# %%
import pandas as pd

# Emplacement
folder = "/Users/gregoiregobert/Downloads/42/knight"
folder = "/home/ggobert/Downloads"


df_test = pd.read_csv(folder + "/Test_knight.csv")
df_Train = pd.read_csv(folder + "/Train_knight.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 2, figsize=(10, 8))

sns.scatterplot(df_Train, x='Sensitivity', y='Hability', hue='knight', ax=axes[0, 0])
sns.scatterplot(df_test, x='Sensitivity', y='Hability', ax=axes[1, 0])
sns.scatterplot(df_Train, x='Reactivity', y='Survival', hue='knight', ax=axes[0, 1])
sns.scatterplot(df_test, x='Reactivity', y='Survival', ax=axes[1, 1])
# Out:
# <Axes: xlabel='Reactivity', ylabel='Survival'>
