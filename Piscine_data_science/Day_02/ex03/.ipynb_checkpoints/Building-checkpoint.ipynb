# %%
import psycopg2
import matplotlib.pyplot as plt
import pandas as pd

# Connecting to the Database
print("Trying to connect to db")
conn = psycopg2.connect(
    database="piscineds",
    user="ggobert",
    password="mysecretpassword",
    host=0
)
print("Connection success!")

cur = conn.cursor()
cur.execute(""" SELECT event_type, price, user_id FROM  customers """)
results = cur.fetchall()

colnames = [desc[0] for desc in cur.description]

df = pd.DataFrame(results, columns=colnames)

cur.close()
conn.close()
# Out:
# Trying to connect to db
# Connection success!

# %%
df = df[df['event_type'] == 'purchase']
frequency = df.groupby(['user_id', 'event_type']).size().reset_index(name='frequency')
max_frequency = frequency['frequency'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = df[df['event_type'] == 'purchase']
#       2 frequency = df.groupby(['user_id', 'event_type']).size().reset_index(name='frequency')
#       3 max_frequency = frequency['frequency'].max()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(8, 6))
plt.hist(frequency['frequency'], bins=50, edgecolor='white')
plt.xlim(0 ,50)
plt.xlabel('frequency')
plt.ylabel('customers')
plt.show()

# %% [markdown]
# Barchart Altarian dollars by customers

# %%
total_spent = df.groupby('user_id')['price'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 total_spent = df.groupby('user_id')['price'].sum().reset_index()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.bar(total_spent['user_id'], total_spent['price'], edgecolor='black')
#       4 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:2870, in bar(x, height, width, bottom, align, data, **kwargs)
#    2859 @_copy_docstring_and_deprecators(Axes.bar)
#    2860 def bar(
#    2861     x: float | ArrayLike,
#    (...)
#    2868     **kwargs,
#    2869 ) -> BarContainer:
# -> 2870     return gca().bar(
#    2871         x,
#    2872         height,
#    2873         width=width,
#    2874         bottom=bottom,
#    2875         align=align,
#    2876         **({"data": data} if data is not None else {}),
#    2877         **kwargs,
#    2878     )
#
# ...
